# %%
import numpy as np
from skimage import img_as_float
from skimage.io import imread
from pylab import *

# %%
Img = imread('/home/cries/Workshop/3D-object_Nabil/cdast.jpg')
figure(figsize=(3, 3))
imshow(Img, 'gray'); axis('off')
# Out:
# (-0.5, 749.5, 881.5, -0.5)

# %% [markdown]
# #### Constant Parameter (First Reference)

# %%
luminosity_constant = [0.21,0.72,0.07]
gray_lumin_Img = np.dot(Img[...,:3], luminosity_constant).astype(np.uint8)
figure(figsize=(2, 2))
imshow(gray_lumin_Img, 'gray'); axis('off')
# Out:
# (-0.5, 749.5, 881.5, -0.5)

# %% [markdown]
# #### Constant Parameter (Second Reference)

# %%
w, h = Img.shape[:2]
R = Img[:,:,0]
G = Img[:,:,1]
B = Img[:,:,2]
# subplot(1,4,1); imshow(Img, 'gray'); title("RGB"); axis('off')
# subplot(1,4,2); imshow(R, 'gray'); title("Red"); axis('off')
# subplot(1,4,3); imshow(G, 'gray'); title("Green"); axis('off')
# subplot(1,4,4); imshow(B, 'gray'); title("Blue"); axis('off')
# show() 
test2_Img = (0.2989*R + 0.5870*G + 0.1141*B).astype(np.uint8)
figure(figsize=(2, 2))
imshow(test2_Img, 'gray'); axis('off')
# Out:
# (-0.5, 749.5, 881.5, -0.5)
